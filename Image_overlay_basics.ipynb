# %% [markdown]
# <a href="https://colab.research.google.com/github/nikitas25644/Blind-Machine-Operations/blob/main/Image_overlay_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img=np.zeros([50,50,3])
img[:,:,0]=1
img[:,:,1]=1
img[:,:,2]=1

# %%
plt.figure(figsize=(5,5))
plt.imshow(img)

# %%
img[23:27,23:27,1:]=0
plt.figure(figsize=(5,5))
plt.imshow(img)

# %%
img1=cv2.imread("/content/drive/MyDrive/M-N-P/Nikita phone/IMG_20211212_162624.jpg")
plt.figure(figsize=(15,10))
plt.imshow(img1)

# %%
print(img1.shape)
# Out:
# (1800, 4000, 3)

# %%
img2=np.flip(img1,axis=1)    
plt.figure(figsize=(15,10))
plt.imshow(img2)

# %%
img3=np.zeros([1800,4000,3])
img3[:,:,:]=1
img3[1000:1250,600:850,:1]=0
plt.figure(figsize=(15,10))
plt.imshow(img3)
